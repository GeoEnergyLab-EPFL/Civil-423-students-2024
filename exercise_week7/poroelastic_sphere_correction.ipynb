# %% [markdown]
# ### Exercise 7. Poroelastic Sphere
#
# The goal of this exercise is to develop a fully-coupled poroelastic code capable of developing fluid pressure and deformations at the same time

# %%
# importing the necessary python modules
# numpy and matplotlib are popular packages for scientific computing and plotting
import numpy as np
import matplotlib.pyplot as plt
import pygmsh

# interactive python (iPython) magic to instruct jupyter how to show the plots with respect to the code cells
# %matplotlib inline

# scipy is an extension for numpy, used extensively in scientific computing
import scipy as sp

# various plotting parameters
plt.rcParams['text.usetex'] = False
plt.rcParams['axes.labelsize'] = 12

# The following lines are though to import the source functions
import sys
sys.path.append('../src')

# And we import the necessary tools from our source folder.
from MesherWrapper import Mesh
from MeshUtils import MeshUtils
import MatrixAssembly
import PoroElasticProperties as prop

# %% [markdown]
# ### Drainage of a poroelastic sphere
#
# The isotropic compression of a poroelastic sphere of homogeneous medium is also called Cryer's sphere. We will compute a numerical solution of the displacement and pressure at every point in the sphere after application of a mechanical load with an initial stress field.
#
# We will start by defining the mesh. Taking advantage of the problem's radial symmetry, we can reduce the domain to a quarter circle and then run axissymetric simmulation.

# %%
# we define the mesh by drawing a quarter cirle of a radius 1.
# important to mention that the closed loop should have nodes called in counter-clockwise direction
r = 1
cell_size = 0.05

with pygmsh.geo.Geometry() as geom:
    center_point = geom.add_point([0, 0], cell_size)
    top_point = geom.add_point([0, r], cell_size)
    right_point = geom.add_point([r, 0], cell_size)

    left_nodes = geom.add_line(center_point, top_point)
    bottom_nodes = geom.add_line(right_point, center_point)
    arc = geom.add_circle_arc(top_point, center_point, right_point)

    loop = geom.add_curve_loop([-left_nodes, -bottom_nodes, -arc])
    surface = geom.add_plane_surface(loop)
    out = geom.generate_mesh()

mesh = Mesh(out, simultype='axis')
mesh = MeshUtils.tri3_to_tri6(mesh)
mesh.plot()
plt.xlabel('x')
plt.ylabel('y')
print(mesh.number_nodes)
print(mesh.nodes.shape)
# Out:
# 1597
# (1597, 2)

# %%
# geomechanical parameters
k = 8.4e3  # elastic drained bulk modulus [MPa]
g = 6.8e3  # shear modulus [MPa]
b = 0.707692  # biot coefficient
M = 9.18478e3  # biot modulus [MPa]
k_u = k + M * b ** 2
perm = 0.137549e-3  # permeability
mu_f = 1  # fluid viscosity
rho = 1  # density
kappa = perm / mu_f  # conductivity
nu_u = prop.poisson_ratio(g, k_u)  # undrained Poisson ratio
E_u = prop.young_modulus(g, k_u)  # undrained Young modulus
nu = prop.poisson_ratio(g, k)  # Poisson ratio
E = prop.young_modulus(g, k)  # Young modulus

# %% [markdown]
# ### Boundary conditions
#
# We will impose that there are no radial displacements on the left boundary and no vertical displacements on the bottom boundary.
#
# Additionally, the pressure on the outer boundary (circle) will be fixed in the later stages. Here, we will only detect the nodes laying on the external surface of the sphere.
#
# Note that it will be necessary to introduce a rounding as to really capture all the points. This is because we need to account for the numerical imprecision of the meshing.

# %%
# detecting nodes belonging to the left and bottom lines
left_nodes = np.argwhere(mesh.nodes[:, 0] < 1e-3)
bottom_nodes = np.argwhere(mesh.nodes[:, 1] == 0)
# complete the code below
# left_nodes = 
# bottom_nodes

# numbering the corresponding degrees of freedom
fixed_dofx = left_nodes * 2
fixed_dofy = bottom_nodes * 2 + 1

# grouping fixed nodes and fixed dofs and getting rid of duplicates
fixed_nodes = np.unique((bottom_nodes, left_nodes))
fixed_dof = np.unique((fixed_dofx, fixed_dofy))
# complete the code below
# fixed_nodes = 
# fixed_dof = 

# detecting nodes at the external surface of the sphere
radius = np.linalg.norm(mesh.nodes, axis=1)
surface_nodes = np.argwhere(np.abs(radius - r) <= 1e-3)
# complete the code below
# surface_nodes = 

mesh.plot()
plt.scatter(*mesh.nodes[surface_nodes].T, zorder=10)
plt.scatter(*mesh.nodes[fixed_nodes].T, zorder=10)

# %% [markdown]
# ### Defining an initial stress field
#
# As an initial condition we will set a unifrom hydrostatic stress field with values equal to -1 (compression). Note that it would also be possible
# to define the initial state by a traction applied on the boundary which results in the same final result.
# The stress vector in axissymmetry is defined as
#
# $$ \sigma = \left(\sigma_{rr}\ \sigma_{zz}\ \tau_{rz}\ \sigma_{\theta \theta}\right)^\intercal.$$
#
# We will apply an isotropic stress field of unity with the ``set_stress_field`` function. This outputs a vector of internal forces of length ``2 * mesh.nn``, giving the two components of internal force at each node.
#
# Within the bulk and on the free boundaries (natural Neumann BC), vector of internal forces has to be zero for a static body. This happens because of forces originating from neighboring elements are equilibrating at a node. At the Dirichlet boundaries, the internal forces vector is not zero and it equals to the reaction force.

# %%
# initial stress field
sig_unif = [-1, -1, 0, -1]
int_force_0 = MatrixAssembly.set_stress_field(mesh, sig_unif)

# let's plot the internal forces field
# we can reshape the int_force_0 vector to a shape (2, mesh.number_nodes)
s0 = int_force_0.reshape(2, -1, order='F')
mesh.plot(s0[0], c='none', shading='flat')
mesh.plot(s0[1], c='none', shading='flat')
mesh.plot(np.linalg.norm(s0, axis=0), c='gray', shading='flat')
# Out:
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: >,
#  <matplotlib.colorbar.Colorbar at 0x10f1f4af0>)

# %% [markdown]
# ### Matrix assembly
# In the previous exercises, we have coded up the conductivity matrix $\mathbf{C}$, the mass matric $\mathbf{M}$ and the stiffness matrix $\mathbf{K}$. Now, to fully couple porous flow and elasticity, we need to assemble the *coupling* matrix $\mathbf{A}$.

# %%
# assembling the different matrices
K = MatrixAssembly.assemble_stiffness_matrix(mesh, E, nu)
S = MatrixAssembly.assemble_mass_matrix(mesh, 1/M)
C = MatrixAssembly.assemble_conductivity_matrix(mesh, kappa)

# you need to complement the function below in its corresponding class MatrixAssembly
A = MatrixAssembly.assemble_coupling_matrix(mesh, b)

# %% [markdown]
# ### Undrained conditions
#
# The solution at $t=0$ corresponds to the undrained conditions. We will need to assemble the full matrix $\mathbf{T}$, containing the previously defined matrices. At this step, the pressure on the sphere surface is not.

# %%
# we can now solve the undrained case
dt = 0.
# bottom right part of the full matrix
SC = S + dt *C

# getting number of degrees of freedom for each subproblem
ntot_E = K.shape[0]
ntot_P = S.shape[0]
ntot = ntot_E + ntot_P

# assembling the full matrix
top = sp.sparse.hstack((K, -A), format='csc')
bottom = sp.sparse.hstack((-A.T, - SC), format='csc')
# complete the code below
# top = sp.sparse.hstack((..., ...), format='csc')
# bottom = sp.sparse.hstack((..., ...), format='csc')
T = sp.sparse.vstack((top, bottom), format='csc')

# setting the force vector to the initial conditions
Ftot = np.zeros(ntot)
Ftot[:ntot_E] = int_force_0

# getting the numbers of free degrees of freedom
eq_free_disp = np.setdiff1d(np.arange(ntot_E), fixed_dof)
eq_free_p = np.arange(ntot_P) + ntot_E
eq_free = np.hstack((eq_free_disp, eq_free_p))

# %%
# solving the system
undrained_sol = np.zeros(ntot)
undrained_sol[eq_free] = sp.sparse.linalg.spsolve(T[eq_free][:, eq_free], Ftot[eq_free])

# undrained sol has the shape (2 * mesh.nn + mesh.nn, 1), corresponding to the x and y displacements and the pressure.
# we can reshape this vector to access the pressure and displaements easily
pressure_undrained = undrained_sol[ntot_E:]
disp_undrained = undrained_sol[:ntot_E].reshape(2, -1, order='F')
# complete the code below:
# pressure_undrained = 
# disp_undrained =

# %%
# %matplotlib inline
fig, ax, cb = mesh.plot(pressure_undrained, shading='flat')
ax.set_title('pressure (m)', loc='left')

fig, ax, cb = mesh.plot(disp_undrained[0])
ax.set_title('$u_x$ (m)', loc='left')

fig, ax, cb = mesh.plot(disp_undrained[1])
ax.set_title('$u_y$ (m)', loc='left')

factor = 1000
fig, ax, cb = mesh.plot(factor * np.linalg.norm(disp_undrained, axis=0), c='k')
ax.triplot(*(mesh.nodes.T + factor * disp_undrained), c='tab:red', lw=0.5)
ax.set_title(f'displacement (m) ({factor} x multiplication) ', loc='left')
# Out:
# Text(0.0, 1.0, 'displacement (m) (1000 x multiplication) ')

# %% [markdown]
# ### Solving the drained response for $t > 0$
#
# Using a constant time step, we can now:
#
# - assemble a full matrix where $\Delta t$ is not zero and
# - set the pressure at the outer boundary to be fixed at zero.
#
# We will use the previously seen scheme to solve the time evolution between $t=0$ and $t=1$.
#
# Note that as the time-step is constant, we can perform a LU factorization of the global matrix in order to significanly speed up the solution of the linear system at each time-step.

# %%
# set up a time step
dt = 0.0025
# build a vector of time linearly increasing from 0 to 1 with the given timestep
t = np.arange(0, 1, dt)
# complete the code below
# t = 

# reassemble the bottom right part of the full matrix
SC = S + dt * C
# complete the code below:
# SC =

# update the corresponding part of the full matrix
# complete the code below:
# bottom =
bottom = sp.sparse.hstack((-A.T, - SC), format='csc')
T = sp.sparse.vstack((top, bottom), format='csc')

# create empty arrays for pressure and displacement having number of timesteps as the number of rows
pressure = np.zeros((len(t), mesh.number_nodes))
displacement = np.zeros((len(t), 2, mesh.number_nodes))
# complete the code below:
# pressure = 
# displacement = 

# create a copy of undrained solution and use it as a previous step solution
sol = undrained_sol.copy()
# fix the pressure to zero on the surface 
# [+ ntot_E] is displacing the pressure DOFs within the vector of unknowns
sol[surface_nodes + ntot_E] = 0

# redefining the free degrees of freedom (as it changes in pressure)
eq_free_disp = np.setdiff1d(np.arange(ntot_E), fixed_dof)
eq_free_p = np.setdiff1d(np.arange(ntot_P), surface_nodes) + ntot_E
eq_free = np.hstack((eq_free_disp, eq_free_p))

# call to superLU to get the LU factorization of the matrix 
# valid when the time-step is kept constant.
# complete below
# Tinv = sp.sparse.linalg.splu(T[...][...]) 
Tinv = sp.sparse.linalg.splu(T[eq_free][:, eq_free])   # has a solve method to quickly solve a linear system using the factorization

# time loop 
rhs = np.zeros(ntot)
for i in range(len(t)):
    print(f'\ time step # {i+1} out of {len(t)}', end='\n')

    # calculate the change in nodal flux (scalar)
    rhs[eq_free_p] = dt * C[eq_free_p - ntot_E].dot(sol[ntot_E:])

    # solve the system for the increment
    # complete the code below
    # delta_x =
    delta_x = Tinv.solve(rhs[eq_free])

    # update the solution
    sol[eq_free] += delta_x
    # complete the code below
    # sol[...] 

    # fill in corresponding rows of pressure and displacement arrays
    pressure[i] = sol[ntot_E:]
    displacement[i] = sol[:ntot_E].reshape(2, -1, order='F')
    # complete the code below
    # pressure[...] = 
    # displacement[...] =
# Out:
# \ time step # 1 out of 400
# \ time step # 2 out of 400
# \ time step # 3 out of 400
# \ time step # 4 out of 400
# \ time step # 5 out of 400
# \ time step # 6 out of 400
# \ time step # 7 out of 400
# \ time step # 8 out of 400
# \ time step # 9 out of 400
# \ time step # 10 out of 400
# \ time step # 11 out of 400
# \ time step # 12 out of 400
# \ time step # 13 out of 400
# \ time step # 14 out of 400
# \ time step # 15 out of 400
# \ time step # 16 out of 400
# \ time step # 17 out of 400
# \ time step # 18 out of 400
# \ time step # 19 out of 400
# \ time step # 20 out of 400
# \ time step # 21 out of 400
# \ time step # 22 out of 400
# \ time step # 23 out of 400
# \ time step # 24 out of 400
# \ time step # 25 out of 400
# \ time step # 26 out of 400
# \ time step # 27 out of 400
# \ time step # 28 out of 400
# \ time step # 29 out of 400
# \ time step # 30 out of 400
# \ time step # 31 out of 400
# \ time step # 32 out of 400
# \ time step # 33 out of 400
# \ time step # 34 out of 400
# \ time step # 35 out of 400
# \ time step # 36 out of 400
# \ time step # 37 out of 400
# \ time step # 38 out of 400
# \ time step # 39 out of 400
# \ time step # 40 out of 400
# \ time step # 41 out of 400
# \ time step # 42 out of 400
# \ time step # 43 out of 400
# \ time step # 44 out of 400
# \ time step # 45 out of 400
# \ time step # 46 out of 400
# \ time step # 47 out of 400
# \ time step # 48 out of 400
# \ time step # 49 out of 400
# \ time step # 50 out of 400
# \ time step # 51 out of 400
# \ time step # 52 out of 400
# \ time step # 53 out of 400
# \ time step # 54 out of 400
# \ time step # 55 out of 400
# \ time step # 56 out of 400
# \ time step # 57 out of 400
# \ time step # 58 out of 400
# \ time step # 59 out of 400
# \ time step # 60 out of 400
# \ time step # 61 out of 400
# \ time step # 62 out of 400
# \ time step # 63 out of 400
# \ time step # 64 out of 400
# \ time step # 65 out of 400
# \ time step # 66 out of 400
# \ time step # 67 out of 400
# \ time step # 68 out of 400
# \ time step # 69 out of 400
# \ time step # 70 out of 400
# \ time step # 71 out of 400
# \ time step # 72 out of 400
# \ time step # 73 out of 400
# \ time step # 74 out of 400
# \ time step # 75 out of 400
# \ time step # 76 out of 400
# \ time step # 77 out of 400
# \ time step # 78 out of 400
# \ time step # 79 out of 400
# \ time step # 80 out of 400
# \ time step # 81 out of 400
# \ time step # 82 out of 400
# \ time step # 83 out of 400
# \ time step # 84 out of 400
# \ time step # 85 out of 400
# \ time step # 86 out of 400
# \ time step # 87 out of 400
# \ time step # 88 out of 400
# \ time step # 89 out of 400
# \ time step # 90 out of 400
# \ time step # 91 out of 400
# \ time step # 92 out of 400
# \ time step # 93 out of 400
# \ time step # 94 out of 400
# \ time step # 95 out of 400
# \ time step # 96 out of 400
# \ time step # 97 out of 400
# \ time step # 98 out of 400
# \ time step # 99 out of 400
# \ time step # 100 out of 400
# \ time step # 101 out of 400
# \ time step # 102 out of 400
# \ time step # 103 out of 400
# \ time step # 104 out of 400
# \ time step # 105 out of 400
# \ time step # 106 out of 400
# \ time step # 107 out of 400
# \ time step # 108 out of 400
# \ time step # 109 out of 400
# \ time step # 110 out of 400
# \ time step # 111 out of 400
# \ time step # 112 out of 400
# \ time step # 113 out of 400
# \ time step # 114 out of 400
# \ time step # 115 out of 400
# \ time step # 116 out of 400
# \ time step # 117 out of 400
# \ time step # 118 out of 400
# \ time step # 119 out of 400
# \ time step # 120 out of 400
# \ time step # 121 out of 400
# \ time step # 122 out of 400
# \ time step # 123 out of 400
# \ time step # 124 out of 400
# \ time step # 125 out of 400
# \ time step # 126 out of 400
# \ time step # 127 out of 400
# \ time step # 128 out of 400
# \ time step # 129 out of 400
# \ time step # 130 out of 400
# \ time step # 131 out of 400
# \ time step # 132 out of 400
# \ time step # 133 out of 400
# \ time step # 134 out of 400
# \ time step # 135 out of 400
# \ time step # 136 out of 400
# \ time step # 137 out of 400
# \ time step # 138 out of 400
# \ time step # 139 out of 400
# \ time step # 140 out of 400
# \ time step # 141 out of 400
# \ time step # 142 out of 400
# \ time step # 143 out of 400
# \ time step # 144 out of 400
# \ time step # 145 out of 400
# \ time step # 146 out of 400
# \ time step # 147 out of 400
# \ time step # 148 out of 400
# \ time step # 149 out of 400
# \ time step # 150 out of 400
# \ time step # 151 out of 400
# \ time step # 152 out of 400
# \ time step # 153 out of 400
# \ time step # 154 out of 400
# \ time step # 155 out of 400
# \ time step # 156 out of 400
# \ time step # 157 out of 400
# \ time step # 158 out of 400
# \ time step # 159 out of 400
# \ time step # 160 out of 400
# \ time step # 161 out of 400
# \ time step # 162 out of 400
# \ time step # 163 out of 400
# \ time step # 164 out of 400
# \ time step # 165 out of 400
# \ time step # 166 out of 400
# \ time step # 167 out of 400
# \ time step # 168 out of 400
# \ time step # 169 out of 400
# \ time step # 170 out of 400
# \ time step # 171 out of 400
# \ time step # 172 out of 400
# \ time step # 173 out of 400
# \ time step # 174 out of 400
# \ time step # 175 out of 400
# \ time step # 176 out of 400
# \ time step # 177 out of 400
# \ time step # 178 out of 400
# \ time step # 179 out of 400
# \ time step # 180 out of 400
# \ time step # 181 out of 400
# \ time step # 182 out of 400
# \ time step # 183 out of 400
# \ time step # 184 out of 400
# \ time step # 185 out of 400
# \ time step # 186 out of 400
# \ time step # 187 out of 400
# \ time step # 188 out of 400
# \ time step # 189 out of 400
# \ time step # 190 out of 400
# \ time step # 191 out of 400
# \ time step # 192 out of 400
# \ time step # 193 out of 400
# \ time step # 194 out of 400
# \ time step # 195 out of 400
# \ time step # 196 out of 400
# \ time step # 197 out of 400
# \ time step # 198 out of 400
# \ time step # 199 out of 400
# \ time step # 200 out of 400
# \ time step # 201 out of 400
# \ time step # 202 out of 400
# \ time step # 203 out of 400
# \ time step # 204 out of 400
# \ time step # 205 out of 400
# \ time step # 206 out of 400
# \ time step # 207 out of 400
# \ time step # 208 out of 400
# \ time step # 209 out of 400
# \ time step # 210 out of 400
# \ time step # 211 out of 400
# \ time step # 212 out of 400
# \ time step # 213 out of 400
# \ time step # 214 out of 400
# \ time step # 215 out of 400
# \ time step # 216 out of 400
# \ time step # 217 out of 400
# \ time step # 218 out of 400
# \ time step # 219 out of 400
# \ time step # 220 out of 400
# \ time step # 221 out of 400
# \ time step # 222 out of 400
# \ time step # 223 out of 400
# \ time step # 224 out of 400
# \ time step # 225 out of 400
# \ time step # 226 out of 400
# \ time step # 227 out of 400
# \ time step # 228 out of 400
# \ time step # 229 out of 400
# \ time step # 230 out of 400
# \ time step # 231 out of 400
# \ time step # 232 out of 400
# \ time step # 233 out of 400
# \ time step # 234 out of 400
# \ time step # 235 out of 400
# \ time step # 236 out of 400
# \ time step # 237 out of 400
# \ time step # 238 out of 400
# \ time step # 239 out of 400
# \ time step # 240 out of 400
# \ time step # 241 out of 400
# \ time step # 242 out of 400
# \ time step # 243 out of 400
# \ time step # 244 out of 400
# \ time step # 245 out of 400
# \ time step # 246 out of 400
# \ time step # 247 out of 400
# \ time step # 248 out of 400
# \ time step # 249 out of 400
# \ time step # 250 out of 400
# \ time step # 251 out of 400
# \ time step # 252 out of 400
# \ time step # 253 out of 400
# \ time step # 254 out of 400
# \ time step # 255 out of 400
# \ time step # 256 out of 400
# \ time step # 257 out of 400
# \ time step # 258 out of 400
# \ time step # 259 out of 400
# \ time step # 260 out of 400
# \ time step # 261 out of 400
# \ time step # 262 out of 400
# \ time step # 263 out of 400
# \ time step # 264 out of 400
# \ time step # 265 out of 400
# \ time step # 266 out of 400
# \ time step # 267 out of 400
# \ time step # 268 out of 400
# \ time step # 269 out of 400
# \ time step # 270 out of 400
# \ time step # 271 out of 400
# \ time step # 272 out of 400
# \ time step # 273 out of 400
# \ time step # 274 out of 400
# \ time step # 275 out of 400
# \ time step # 276 out of 400
# \ time step # 277 out of 400
# \ time step # 278 out of 400
# \ time step # 279 out of 400
# \ time step # 280 out of 400
# \ time step # 281 out of 400
# \ time step # 282 out of 400
# \ time step # 283 out of 400
# \ time step # 284 out of 400
# \ time step # 285 out of 400
# \ time step # 286 out of 400
# \ time step # 287 out of 400
# \ time step # 288 out of 400
# \ time step # 289 out of 400
# \ time step # 290 out of 400
# \ time step # 291 out of 400
# \ time step # 292 out of 400
# \ time step # 293 out of 400
# \ time step # 294 out of 400
# \ time step # 295 out of 400
# \ time step # 296 out of 400
# \ time step # 297 out of 400
# \ time step # 298 out of 400
# \ time step # 299 out of 400
# \ time step # 300 out of 400
# \ time step # 301 out of 400
# \ time step # 302 out of 400
# \ time step # 303 out of 400
# \ time step # 304 out of 400
# \ time step # 305 out of 400
# \ time step # 306 out of 400
# \ time step # 307 out of 400
# \ time step # 308 out of 400
# \ time step # 309 out of 400
# \ time step # 310 out of 400
# \ time step # 311 out of 400
# \ time step # 312 out of 400
# \ time step # 313 out of 400
# \ time step # 314 out of 400
# \ time step # 315 out of 400
# \ time step # 316 out of 400
# \ time step # 317 out of 400
# \ time step # 318 out of 400
# \ time step # 319 out of 400
# \ time step # 320 out of 400
# \ time step # 321 out of 400
# \ time step # 322 out of 400
# \ time step # 323 out of 400
# \ time step # 324 out of 400
# \ time step # 325 out of 400
# \ time step # 326 out of 400
# \ time step # 327 out of 400
# \ time step # 328 out of 400
# \ time step # 329 out of 400
# \ time step # 330 out of 400
# \ time step # 331 out of 400
# \ time step # 332 out of 400
# \ time step # 333 out of 400
# \ time step # 334 out of 400
# \ time step # 335 out of 400
# \ time step # 336 out of 400
# \ time step # 337 out of 400
# \ time step # 338 out of 400
# \ time step # 339 out of 400
# \ time step # 340 out of 400
# \ time step # 341 out of 400
# \ time step # 342 out of 400
# \ time step # 343 out of 400
# \ time step # 344 out of 400
# \ time step # 345 out of 400
# \ time step # 346 out of 400
# \ time step # 347 out of 400
# \ time step # 348 out of 400
# \ time step # 349 out of 400
# \ time step # 350 out of 400
# \ time step # 351 out of 400
# \ time step # 352 out of 400
# \ time step # 353 out of 400
# \ time step # 354 out of 400
# \ time step # 355 out of 400
# \ time step # 356 out of 400
# \ time step # 357 out of 400
# \ time step # 358 out of 400
# \ time step # 359 out of 400
# \ time step # 360 out of 400
# \ time step # 361 out of 400
# \ time step # 362 out of 400
# \ time step # 363 out of 400
# \ time step # 364 out of 400
# \ time step # 365 out of 400
# \ time step # 366 out of 400
# \ time step # 367 out of 400
# \ time step # 368 out of 400
# \ time step # 369 out of 400
# \ time step # 370 out of 400
# \ time step # 371 out of 400
# \ time step # 372 out of 400
# \ time step # 373 out of 400
# \ time step # 374 out of 400
# \ time step # 375 out of 400
# \ time step # 376 out of 400
# \ time step # 377 out of 400
# \ time step # 378 out of 400
# \ time step # 379 out of 400
# \ time step # 380 out of 400
# \ time step # 381 out of 400
# \ time step # 382 out of 400
# \ time step # 383 out of 400
# \ time step # 384 out of 400
# \ time step # 385 out of 400
# \ time step # 386 out of 400
# \ time step # 387 out of 400
# \ time step # 388 out of 400
# \ time step # 389 out of 400
# \ time step # 390 out of 400
# \ time step # 391 out of 400
# \ time step # 392 out of 400
# \ time step # 393 out of 400
# \ time step # 394 out of 400
# \ time step # 395 out of 400
# \ time step # 396 out of 400
# \ time step # 397 out of 400
# \ time step # 398 out of 400
# \ time step # 399 out of 400
# \ time step # 400 out of 400

# %% [markdown]
# ### Comparison with an analytical solution
# The analytical solution is contained in the file ``PP-Sphere-ohio.csv`` and shows the pressure at the center of our poroelastic sphere. We will need to extract the nodes at this location. We can also look at the displacements at the outer boundary of the sphere (and only one point is needed because of the symmetry).

# %%
top_point = np.argwhere((mesh.nodes[:, 0] <= 1e-3) & (np.abs(mesh.nodes[:, 1] - r) <= 1e-3))[:, 0]
center_point = np.argwhere((mesh.nodes[:, 0] <= 1e-3) & (mesh.nodes[:, 1] <= 1e-3))[:, 0]
right = np.argwhere((mesh.nodes[:, 1] <= 1e-3) & (np.abs(mesh.nodes[:, 0] - r) <= 1e-3))[:, 0]

mesh.plot()
plt.scatter(*mesh.nodes[top_point].T)
plt.scatter(*mesh.nodes[right].T)
plt.scatter(*mesh.nodes[center_point].T)

# %%
# %matplotlib inline
analt, analp = np.loadtxt('PP-Sphere-ohio.csv', delimiter=',').T
plt.plot(analt, analp, label='analytical solution', c='k')
plt.plot(t, pressure[:, center_point], lw=0, marker='.', ms=10, markevery=0.025, label='numerical solution', c='tab:red')

plt.legend(frameon=False)
plt.xlabel('t (s)')
plt.ylabel('pressure (m)')
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
# we can also look at the displacementes at the boundary
# however here we have no analytical solution to compare with
norm = np.linalg.norm(displacement, axis=1)
plt.plot(t, norm[:, top_point], label='top')
plt.plot(t, norm[:, right], label='right')
plt.legend(title='total displacement', frameon=False)
plt.xlabel('t (s)')
plt.ylabel('displacement (m)')
# Out:
# Text(0, 0.5, 'displacement (m)')

# %%
# %matplotlib qt
# we can animate the pressure evolution

from matplotlib.animation import FuncAnimation

fig = plt.figure()
ax = fig.add_subplot()
im = ax.tripcolor(*mesh.nodes.T, mesh.connectivity[:, :3], pressure[0], lw=1, shading='gouraud')
plt.colorbar(im, label='Pressure [Pa]')
mesh.plot(ax=ax, c='gray')
ax.set_aspect(1)
ax.set_xlabel('r [m]')
ax.set_ylabel('z [m]')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
time = ax.set_title('Pressure at t=0')

def delta_x(i):
    time.set_text(f'Pressure at t={t[i]:.2f}')
    im.set_array(pressure[i])
    return im, time

ani = FuncAnimation(fig, delta_x, frames=int(len(t)/2), interval=5)
